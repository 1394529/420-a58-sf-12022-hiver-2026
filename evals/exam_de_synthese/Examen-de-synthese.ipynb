# %% [markdown]
# **420-A58-SF - Algorithmes d'apprentissage non supervisé - Hiver 2026 - Spécialisation technique en Intelligence Artificielle**<br/>
# MIT License - Copyright (c) 2026 Mikaël Swawola
#
# # Examen de synthèse

# %% [markdown]
# | | |
# |---|---|
# | **Durée** | 3 heures 30 minutes |
# | **Travail** | Individuel |
# | **Documents** | Autorisés |
# | **Remise** | Remettre ce notebook complété sur Lea |

# %% [markdown]
# ---
# ## Engagement
#
# En soumettant ce travail, je certifie sur l'honneur avoir respecté l'ensemble des règles d'intégrité académique et ne pas avoir eu recours à des logiciels d'intelligence artificielle générative ni à l'aide de tiers pour le réaliser. Je comprends que toute violation de ces règles peut entraîner des sanctions académiques.
#
# Inscrivez votre nom complet : _____________________________
#
# Date : _____________________________
#
# **Tout refus de signer cet engagement entraînera une note nulle à cette évaluation sommative.**

# %% [markdown]
# * Cet examen couvre l'ensemble des chapitres du cours *420-A58-SF - Apprentisage non supervisé*. Des connaissances des *cours 420-A55-SF - Analyse exploratoire des données* et *420-A56-SF - Transformation de données* relatives à l'apprentissage non supervisé peuvent être requises.
# * Vous devrez rendre les fichiers `Examen-de-synthese.ipynb` et `Examen-de-synthese.Rmd` complétés de **vos réponses et de votre code** sur la plateforme Lea à la fin de l'examen.
# * Renommez les fichiers en incluant vos noms et prénoms. Exemple: **Examen-de-synthese_&lt;nom&gt;_&lt;prenom&gt;.ipynb** et **Examen-de-synthese_&lt;nom&gt;_&lt;prenom&gt;.Rmd**
# * L'examen est composé de 4 parties indépendantes. Elles peuvent être réalisées dans l'ordre de votre choix
# * <strong style='color: red'>Lisez bien les questions</strong> et **bon succès à tous !**

# %% [markdown]
# ---
# ## Barème

# %% [markdown]
# * **L'examen est noté sur 100 points**
# * Chaque partie compte pour 25 points
#
# | Partie | Question | Points |
# |--------|----------|--------|
# | **Partie 1 — Partitionnement des états américains (25 points)** | | |
# | | Q1-1 | 5 |
# | | Q1-3 | 15 |
# | | Q1-4 | 5 |
# | **Partie 2 — Expression de gènes (25 points)** | | |
# | | Q2-1 | 2.5 |
# | | Q2-2 | 2.5 |
# | | Q2-3 | 10 |
# | | Q2-4 | 10 |
# | **Partie 3 — Recommandation de films (25 points)** | | |
# | | Q3-1 | 5 |
# | | Q3-2 | 20 |
# | **Partie 4 — Analyse des tâches solaires (25 points)** | | |
# | | Q4-1 | 2 |
# | | Q4-2 | 2 |
# | | Q4-3 | 2 |
# | | Q4-4 | 8 |
# | | Q4-5 | 4 |
# | | Q4-6 | 4 |
# | | Q4-7 | 3 |
# | **Total** | | **100** |

# %% [markdown]
# ---
# ## Bibliothèques logicielles

# %% [markdown]
# Importez ci-dessous les bibliothèques logicielles que vous jugerez utiles pour répondre aux questions de l'examen. Cette partie est à compléter au fur et à mesure que vous répondrez aux questions.

# %% [markdown]
# #### ----- Insérer l'importation des bibliothèques ci-dessous -----

# %% [markdown]
# ---
# ## Partie 1 - Partitionnement des états américains (25 points)

# %% [markdown]
# Cette première partie de l'examen consiste à mettre en oeuvre un algorithme de partitionnement judicieusement sélectionné afin de regrouper les états américains présentant des "ressemblances". Les données sont contenues dans le fichiers `unclesam.csv` disponible dans le répertoire `data`.

# %% [markdown]
# #### Question 1-1 - Charger le jeu de données `unclesam.csv`. Utiliser le nom de l'état comme index de la trame de données. Combien d'états américains sont représentés ? Combien de colonnes y a-t-il ? (5 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 1-3 - Appliquer un algorithme de partitionnement sur le jeu de données. Identifier un nombre de clusters en utilisant une méthode pertinente. (15 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 1-4 - Visualisez les clusters obtenus et conclure sur la pertinence des résultats. (5 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# ---
# ## Partie 2 - Expression de gènes (25 points)

# %% [markdown]
# Cette seconde partie de l'examen est consacrée à l'étude de l'expression de gènes en oncologie. Le jeu de données "genes" contient les expressions d'un gène mesurée à 100 instants différents pour 100 échantillons de tissus. L'expression d'un gène peut être "Up" ou "Down" et chaque échantillon correspond éventuellement à la présence d'une maladie. Les données sont contenues dans le fichiers `genes.csv` disponible dans le répertoire `data`.

# %% [markdown]
# À titre d'illustration, pour l'échantillon 1 (sample 1), les expressions d'un gène mesurées pour 100 instants différents sont représentées par:
#
# **sample1	1U	2U	3D	4U	5D	6U	...	95U	96D	97D	98D	99U	100D**
#
# Dans l'exemple précédent, l'expression est "Up" à l'instant 1, "Up" à l'instant 2, "Down" à l'instant 3, etc...
#
# L'objectif de l'exercice consiste donc à trouver les expressions de gènes apparaissant fréquemment. La paire {44D, 72U} apparait par exemple 49 fois).
#
# **La colonne `maladie` ne sera pas exploitée dans cet examen.**

# %% [markdown]
# #### Question 2-1 - Chargez le jeu de données `genes.csv` (2.5 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 2-2 - Selon le modèle Market-basket, à quels éléments des données correspondent respectivement les baskets (paniers) et les items (éléments) ? (2.5 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 2-3 - En considérant un seuil de support de 35%, combien d'itemsets sont fréquents ? Quel est le support de l'itemset {13D,	72U, 59U, 44D, 82D} ? (10 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 2-4 - Quel est l'indice de confiance de la règle d'association {96D, 59U} => {72U} ? (10 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# ---
# ## Partie 3 - Recommandation de films (25 points)

# %% [markdown]
# Cet exercice consiste à identifier des films similaires en vue de proposer à l'utilisateur une liste de choix de films à regarder.
#
# Le jeu de données est issu de **MovieLens**, une base de données de notations de films. La matrice d'utilité originale contient les notes (de 1 à 5) données par 943 utilisateurs à 1 682 films. À partir de cette matrice, un **algorithme de filtrage collaboratif** (*collaborative filtering*) a été appliqué pour apprendre, pour chaque film, un **vecteur profile** de dimension $n = 10$.
#
# Ce **vecteur profile** (noté $X$ dans la littérature) représente chaque film comme un point dans un espace de 10 **facteurs latents**. Ces dimensions ne correspondent pas à des caractéristiques directement interprétables (comme le genre ou le réalisateur), mais capturent des **patterns implicites** extraits des habitudes collectives de notation de l'ensemble des utilisateurs. Deux films proches dans cet espace de facteurs latents tendent à être appréciés par les mêmes types d'utilisateurs.
#
# Le **vecteur profile** des 1 682 films est disponible dans le fichier `movie-profile.npz`. C'est avec cette représentation que les films similaires seront identifiés. Les titres des films sont stockés dans `movie_ids.txt`.

# %% [markdown]
# #### Question 3-1 - Charger le vecteur profile des films (`movie-profile.npz`). (5 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# #### Question 3-2 - À l'aide d'un algorithme de recherche, trouvez le film le plus similaire à Star Wars (celui de 1977). Donner son index, sa distance par rapport au film "requête", ainsi que son titre. Préciser la métrique utilisée. (20 points)

# %% [markdown]
# #### ----- Votre réponse ci-dessous -----

# %% [markdown]
# ---
# ## Partie 4 - Analyse des tâches solaires (25 points)

# %% [markdown]
# <strong style="color: red">Cette partie doit être intégralement réalisée (réponses et code) au sein du fichier Examen-de-synthese.Rmd.</strong>

# %% [markdown]
# ---
# ## Fin de l'examen de synthèse
